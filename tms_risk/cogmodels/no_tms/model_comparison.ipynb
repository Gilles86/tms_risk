# %%
import arviz as az
from tms_risk.utils import get_all_behavior
from tms_risk.cogmodels.evidence_model import EvidenceModel, EvidenceModelTwoPriors, EvidenceModelGauss, EvidenceModelTwoPriorsDiminishingUtility, EvidenceModelDiminishingUtility
import pymc as pm
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
traces = {}

for model in list(range(1, 9)) + ['8']:
    traces[f'model {model}'] = az.from_netcdf(f'/data/ds-tmsrisk/derivatives/cogmodels/model-{model}_trace.netcdf')

# %%
comparison = az.compare(traces)
# Out:
# /Users/gdehol/mambaforge/lib/python3.10/site-packages/arviz/stats/stats.py:802: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/gdehol/mambaforge/lib/python3.10/site-packages/arviz/stats/stats.py:802: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/gdehol/mambaforge/lib/python3.10/site-packages/arviz/stats/stats.py:802: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/gdehol/mambaforge/lib/python3.10/site-packages/arviz/stats/stats.py:802: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /Users/gdehol/mambaforge/lib/python3.10/site-packages/arviz/stats/stats.py:802: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(

# %%
labels = {'model 1':'2 evidence sds',
'model 2':'2 evidence sds + different priors',
'model 3':'2 evidence sds (Gauss)',
'model 4':'2 evidence sds + diminishing utility',
'model 5':'2 evidence sds + different priors + diminishing utility',
'model 6':'4 evidence sds',
'model 7':'4 evidence sds + different priors',
'model 8':'Khaw et al.'}

# %%
comparison.index = comparison.index.map(labels)

# %%
comparison
# Out:
#                                                     rank     elpd_loo  \
# 2 evidence sds + different priors + diminishing...     0 -4096.516607
# 2 evidence sds + different priors                      1 -4123.736660
# 4 evidence sds                                         2 -4297.006032
# 4 evidence sds + different priors                      3 -4301.882322
# 2 evidence sds + diminishing utility                   4 -4449.508677
# 2 evidence sds                                         5 -4613.363922
# Khaw et al.                                            6 -4677.444731
# 2 evidence sds (Gauss)                                 7 -4819.729985
#
#                                                          p_loo   elpd_diff  \
# 2 evidence sds + different priors + diminishing...  211.388177    0.000000
# 2 evidence sds + different priors                   189.903176   27.220052
# 4 evidence sds                                      295.203924  200.489425
# 4 evidence sds + different priors                   192.056967  205.365715
# 2 evidence sds + diminishing utility                178.878228  352.992069
# 2 evidence sds                                      147.301358  516.847315
# Khaw et al.                                          87.337885  580.928124
# 2 evidence sds (Gauss)                              193.550228  723.213378
#
#                                                           weight         se  \
# 2 evidence sds + different priors + diminishing...  8.956370e-01  42.389341
# 2 evidence sds + different priors                   2.630632e-07  41.604079
# 4 evidence sds                                      8.022648e-02  43.104983
# 4 evidence sds + different priors                   2.074134e-07  41.431922
# 2 evidence sds + diminishing utility                2.413686e-02  38.108972
# 2 evidence sds                                      6.933926e-08  35.155726
# Khaw et al.                                         5.346104e-08  33.715886
# 2 evidence sds (Gauss)                              0.000000e+00  32.287580
#
#                                                           dse  warning scale
# 2 evidence sds + different priors + diminishing...   0.000000     True   log
# 2 evidence sds + different priors                    5.684679     True   log
# 4 evidence sds                                      23.316651     True   log
# 4 evidence sds + different priors                   21.464872     True   log
# 2 evidence sds + diminishing utility                26.315547    False   log
# 2 evidence sds                                      29.644630    False   log
# Khaw et al.                                         30.778089    False   log
# 2 evidence sds (Gauss)                              33.513852     True   log

# %%
az.plot_compare(comparison)
# Out:
# <AxesSubplot: title={'center': 'Model comparison\nhigher is better'}, xlabel='elpd_loo (log)', ylabel='ranked models'>
