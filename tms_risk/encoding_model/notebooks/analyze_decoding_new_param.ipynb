# %%
import numpy as np
import pandas as pd

import os.path as op
import numpy as np

from tqdm.contrib.itertools import product
import pingouin
from tms_risk.utils.data import get_subjects, get_all_behavior, get_pdf, get_decoding_info, get_all_apriori_roi_labels, Subject
import seaborn as sns

import matplotlib.pyplot as plt


stimulation_palette = sns.color_palette()[2:4]
stimulation_order = ['Vertex', 'IPS']

bids_folder = '/data/ds-tmsrisk/'

# %% [markdown]
# # Only TMS target info

# %%
subjects = [int(sub.subject) for sub in get_subjects(all_tms_conditions=True, exclude_outliers=True)]
sessions = [1, 2, 3]
pca_confounds = [False]
denoise = [True]
smoothed = [False]
# masks = ['NPCr1cm-surface', 'NPCr1cm-cluster', 'NPCr2cm-surface', 'NPCr2cm-cluster']
# n_voxels = [0, 1, 100]
masks = ['NPCr2cm-cluster']
n_voxels = [1]
natural_space = [True]
new_parameterisation = [True]


pred = []
pdfs = []
for (sub, session, pcac, den, smooth, mask, nv, ns, new_par) in product(subjects, sessions, pca_confounds, denoise, smoothed, masks, n_voxels, natural_space, new_parameterisation):

    if not ((session == 1) & (nv == 0)):
        pdfs.append(get_pdf(sub, session, pcac, den, smooth, '/data/ds-tmsrisk/', mask, nv, ns, new_par))
        pred.append(get_decoding_info(sub, session, pcac, den, smooth, '/data/ds-tmsrisk', mask, nv, ns, new_par))
# Out:
#   0%|          | 0/105 [00:00<?, ?it/s]
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space.new_parameterisation/sub-45/func/sub-45_ses-1_mask-NPCr2cm-cluster_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space.new_parameterisation/sub-45/func/sub-45_ses-1_mask-NPCr2cm-cluster_space-T1w_pars.tsv

# %%
pdfs
# Out:
# [                                   5.0           6.0       7.0    \
#  stimulation_condition trial_nr
#  baseline              1         0.011375  2.404971e-03  0.002614
#                        2         0.000852  2.528913e-04  0.000110
#                        3         0.003626  1.250296e-03  0.008377
#                        4         0.025006  2.276719e-02  0.061444
#                        5         0.002587  1.483116e-03  0.002491
#  ...                                  ...           ...       ...
#                        116       0.004750  1.754378e-05  0.000026
#                        117       0.000216  1.176656e-04  0.003144
#                        118       0.002824  5.313844e-04  0.371476
#                        119       0.011289  5.214871e-04  0.004607
#                        120       0.000245  1.675310e-07  0.000034
#
#                                         8.0           9.0       10.0   \
#  stimulation_condition trial_nr
#  baseline              1         6.147666e-09  3.112566e-07  0.026164
#                        2         7.291966e-10  2.368423e-08  0.000152
#                        3         4.288731e-07  2.781265e-04  0.471198
#                        4         9.821553e-09  1.678004e-07  0.000833
#                        5         3.823391e-08  9.284029e-07  0.008631
#  ...                                      ...           ...       ...
#                        116       7.054839e-09  7.998063e-07  0.000270
#                        117       2.513131e-07  2.784078e-05  0.006667
#                        118       1.465279e-05  1.874967e-03  0.112069
#                        119       9.539177e-05  1.037109e-03  0.004543
#                        120       8.418874e-09  2.509639e-06  0.001776
#
#                                     11.0      12.0      13.0      14.0   ...  \
#  stimulation_condition trial_nr                                          ...
#  baseline              1         0.059049  0.091043  0.108457  0.096945  ...
#                        2         0.000297  0.000959  0.002805  0.005712  ...
#                        3         0.056239  0.050393  0.041632  0.027833  ...
#                        4         0.000363  0.000597  0.001695  0.004627  ...
#                        5         0.014345  0.016376  0.018852  0.019745  ...
#  ...                                  ...       ...       ...       ...  ...
#                        116       0.001265  0.002564  0.003634  0.004327  ...
#                        117       0.011131  0.010441  0.009485  0.008868  ...
#                        118       0.056187  0.030328  0.019958  0.015551  ...
#                        119       0.004666  0.005363  0.005917  0.006353  ...
#                        120       0.006290  0.011224  0.014321  0.015769  ...
#
#                                     103.0     104.0     105.0     106.0  \
#  stimulation_condition trial_nr
#  baseline              1         0.004902  0.005066  0.005221  0.005368
#                        2         0.004698  0.004485  0.004292  0.004118
#                        3         0.003274  0.003407  0.003531  0.003647
#                        4         0.006852  0.006806  0.006757  0.006707
#                        5         0.010605  0.010810  0.010999  0.011173
#  ...                                  ...       ...       ...       ...
#                        116       0.002504  0.002493  0.002482  0.002470
#                        117       0.002731  0.002711  0.002692  0.002673
#                        118       0.005621  0.005597  0.005572  0.005547
#                        119       0.010756  0.010764  0.010772  0.010781
#                        120       0.005636  0.005590  0.005546  0.005503
#
#                                     107.0     108.0     109.0     110.0  \
#  stimulation_condition trial_nr
#  baseline              1         0.005506  0.005636  0.005757  0.005871
#                        2         0.003960  0.003818  0.003689  0.003573
#                        3         0.003754  0.003853  0.003943  0.004025
#                        4         0.006656  0.006605  0.006554  0.006504
#                        5         0.011333  0.011479  0.011614  0.011736
#  ...                                  ...       ...       ...       ...
#                        116       0.002459  0.002447  0.002436  0.002424
#                        117       0.002655  0.002637  0.002620  0.002603
#                        118       0.005521  0.005496  0.005470  0.005444
#                        119       0.010790  0.010800  0.010810  0.010820
#                        120       0.005461  0.005420  0.005380  0.005340
#
#                                     111.0     112.0
#  stimulation_condition trial_nr
#  baseline              1         0.005977  0.006076
#                        2         0.003468  0.003372
#                        3         0.004100  0.004166
#                        4         0.006455  0.006407
#                        5         0.011847  0.011949
#  ...                                  ...       ...
#                        116       0.002413  0.002402
#                        117       0.002586  0.002570
#                        118       0.005419  0.005393
#                        119       0.010830  0.010840
#                        120       0.005302  0.005264
#
#  [120 rows x 108 columns],
#                                         5.0           6.0       7.0    \
#  stimulation_condition trial_nr
#  vertex                1         4.513435e-02  6.619606e-04  0.136684
#                        2         5.555808e-03  4.223745e-06  0.001059
#                        3         2.383822e-03  1.308636e-06  0.000911
#                        4         4.704763e-04  3.749784e-08  0.000044
#                        5         9.340296e-03  9.182049e-06  0.001125
#  ...                                      ...           ...       ...
#                        116       3.646848e-07  2.717736e-08  0.000017
#                        117       1.991316e-02  4.158505e-07  0.002944
#                        118       4.558206e-05  2.105327e-07  0.000241
#                        119       1.027547e-04  4.539917e-09  0.000007
#                        120       1.504888e-03  1.589389e-09  0.000016
#
#                                     8.0       9.0       10.0      11.0   \
#  stimulation_condition trial_nr
#  vertex                1         0.129150  0.032781  0.009068  0.000034
#                        2         0.005158  0.004893  0.012089  0.000615
#                        3         0.009893  0.023126  0.007598  0.000001
#                        4         0.001240  0.002683  0.003868  0.000005
#                        5         0.008475  0.007438  0.002566  0.000010
#  ...                                  ...       ...       ...       ...
#                        116       0.000064  0.000108  0.000238  0.000456
#                        117       0.130079  0.096204  0.069639  0.042993
#                        118       0.000666  0.000707  0.001507  0.003134
#                        119       0.000484  0.000628  0.001350  0.003020
#                        120       0.002225  0.002325  0.003770  0.006441
#
#                                     12.0      13.0      14.0   ...     103.0  \
#  stimulation_condition trial_nr                                ...
#  vertex                1         0.000269  0.006143  0.006239  ...  0.009973
#                        2         0.004735  0.017249  0.012306  ...  0.012664
#                        3         0.000036  0.012285  0.024851  ...  0.007921
#                        4         0.000133  0.011055  0.009706  ...  0.015757
#                        5         0.000097  0.005292  0.012483  ...  0.009404
#  ...                                  ...       ...       ...  ...       ...
#                        116       0.000733  0.001075  0.001498  ...  0.010188
#                        117       0.026187  0.017796  0.013541  ...  0.006023
#                        118       0.005039  0.006674  0.007904  ...  0.011164
#                        119       0.005152  0.006927  0.008085  ...  0.005415
#                        120       0.009037  0.010985  0.012298  ...  0.007737
#
#                                     104.0     105.0     106.0     107.0  \
#  stimulation_condition trial_nr
#  vertex                1         0.009981  0.009988  0.009993  0.009998
#                        2         0.012664  0.012664  0.012663  0.012663
#                        3         0.007904  0.007888  0.007873  0.007859
#                        4         0.015766  0.015773  0.015777  0.015781
#                        5         0.009400  0.009397  0.009394  0.009391
#  ...                                  ...       ...       ...       ...
#                        116       0.010196  0.010203  0.010211  0.010218
#                        117       0.006024  0.006025  0.006027  0.006028
#                        118       0.011160  0.011156  0.011152  0.011148
#                        119       0.005408  0.005401  0.005394  0.005387
#                        120       0.007731  0.007726  0.007720  0.007715
#
#                                     108.0     109.0     110.0     111.0  \
#  stimulation_condition trial_nr
#  vertex                1         0.010002  0.010006  0.010009  0.010011
#                        2         0.012662  0.012660  0.012659  0.012658
#                        3         0.007846  0.007833  0.007821  0.007810
#                        4         0.015782  0.015783  0.015783  0.015782
#                        5         0.009388  0.009384  0.009381  0.009379
#  ...                                  ...       ...       ...       ...
#                        116       0.010225  0.010232  0.010239  0.010246
#                        117       0.006029  0.006030  0.006032  0.006033
#                        118       0.011145  0.011141  0.011138  0.011134
#                        119       0.005380  0.005374  0.005368  0.005361
#                        120       0.007710  0.007705  0.007700  0.007696
#
#                                     112.0
#  stimulation_condition trial_nr
#  vertex                1         0.010014
#                        2         0.012657
#                        3         0.007798
#                        4         0.015781
#                        5         0.009376
#  ...                                  ...
#                        116       0.010252
#                        117       0.006034
#                        118       0.011131
#                        119       0.005355
#                        120       0.007691
#
#  [120 rows x 108 columns],
#                                         5.0           6.0       7.0    \
#  stimulation_condition trial_nr
#  ips                   1         1.526286e-03  1.321549e-06  0.000199
#                        2         7.597567e-05  4.039944e-08  0.000007
#                        3         3.281148e-02  2.591145e-02  0.154680
#                        4         1.172844e-02  1.233231e-05  0.002267
#                        5         7.180431e-02  7.804749e-04  0.038408
#  ...                                      ...           ...       ...
#                        116       1.151498e-03  5.675462e-04  0.000447
#                        117       7.890014e-05  3.394229e-05  0.000540
#                        118       4.924441e-06  1.176872e-05  0.002152
#                        119       1.131840e-03  6.111343e-04  0.048691
#                        120       6.313568e-07  7.690528e-07  0.000019
#
#                                         8.0           9.0       10.0   \
#  stimulation_condition trial_nr
#  ips                   1         2.785986e-03  3.400725e-03  0.003631
#                        2         1.740414e-04  2.331589e-04  0.000258
#                        3         2.199420e-02  1.694689e-02  0.016746
#                        4         1.322246e-02  1.326580e-02  0.013007
#                        5         4.607464e-02  3.785900e-02  0.033962
#  ...                                      ...           ...       ...
#                        116       7.425067e-14  1.017874e-09  0.004924
#                        117       7.527811e-13  2.214181e-08  0.014054
#                        118       7.120419e-05  6.077708e-02  0.020876
#                        119       7.220057e-14  1.145493e-09  0.029030
#                        120       1.667856e-16  3.060100e-12  0.000945
#
#                                     11.0      12.0      13.0      14.0   ...  \
#  stimulation_condition trial_nr                                          ...
#  ips                   1         0.003817  0.003973  0.004101  0.004207  ...
#                        2         0.000280  0.000300  0.000318  0.000334  ...
#                        3         0.016525  0.016236  0.015913  0.015579  ...
#                        4         0.012688  0.012342  0.011994  0.011657  ...
#                        5         0.030674  0.027892  0.025550  0.023580  ...
#  ...                                  ...       ...       ...       ...  ...
#                        116       0.017935  0.018482  0.017896  0.017574  ...
#                        117       0.012293  0.009938  0.009650  0.010047  ...
#                        118       0.003816  0.003571  0.003796  0.004098  ...
#                        119       0.067142  0.058028  0.048887  0.042239  ...
#                        120       0.009736  0.011319  0.012397  0.013667  ...
#
#                                     103.0     104.0     105.0     106.0  \
#  stimulation_condition trial_nr
#  ips                   1         0.004910  0.004880  0.004857  0.004839
#                        2         0.000449  0.000454  0.000458  0.000461
#                        3         0.011155  0.011176  0.011193  0.011206
#                        4         0.007915  0.007923  0.007929  0.007933
#                        5         0.010486  0.010439  0.010401  0.010371
#  ...                                  ...       ...       ...       ...
#                        116       0.016670  0.017536  0.018277  0.018903
#                        117       0.015297  0.015626  0.015897  0.016118
#                        118       0.008154  0.008005  0.007884  0.007785
#                        119       0.007738  0.008103  0.008412  0.008669
#                        120       0.018018  0.018420  0.018749  0.019017
#
#                                     107.0     108.0     109.0     110.0  \
#  stimulation_condition trial_nr
#  ips                   1         0.004825  0.004814  0.004806  0.004799
#                        2         0.000464  0.000466  0.000467  0.000468
#                        3         0.011215  0.011222  0.011227  0.011231
#                        4         0.007936  0.007938  0.007939  0.007940
#                        5         0.010348  0.010329  0.010315  0.010303
#  ...                                  ...       ...       ...       ...
#                        116       0.019425  0.019856  0.020207  0.020492
#                        117       0.016297  0.016442  0.016558  0.016651
#                        118       0.007705  0.007641  0.007590  0.007550
#                        119       0.008882  0.009055  0.009195  0.009307
#                        120       0.019233  0.019407  0.019546  0.019657
#
#                                     111.0     112.0
#  stimulation_condition trial_nr
#  ips                   1         0.004795  0.004791
#                        2         0.000469  0.000470
#                        3         0.011234  0.011236
#                        4         0.007941  0.007941
#                        5         0.010294  0.010287
#  ...                                  ...       ...
#                        116       0.020721  0.020903
#                        117       0.016724  0.016783
#                        118       0.007518  0.007493
#                        119       0.009396  0.009465
#                        120       0.019745  0.019814
#
#  [120 rows x 108 columns],
#                                     5.0       6.0       7.0       8.0    \
#  stimulation_condition trial_nr
#  baseline              1         0.002124  0.002325  0.003653  0.005844
#                        2         0.013955  0.013791  0.011411  0.005071
#                        3         0.010662  0.009909  0.005798  0.001504
#                        4         0.016349  0.015951  0.011989  0.004189
#                        5         0.009506  0.010186  0.013760  0.015059
#  ...                                  ...       ...       ...       ...
#                        116       0.004922  0.004928  0.004975  0.004828
#                        117       0.002465  0.002455  0.002312  0.001769
#                        118       0.014944  0.015041  0.016155  0.017636
#                        119       0.012769  0.012853  0.013832  0.015326
#                        120       0.006571  0.006515  0.005766  0.003509
#
#                                     9.0       10.0      11.0      12.0   \
#  stimulation_condition trial_nr
#  baseline              1         0.006228  0.005943  0.004499  0.003124
#                        2         0.002829  0.004676  0.009257  0.012562
#                        3         0.000678  0.001340  0.003872  0.007260
#                        4         0.002040  0.003786  0.009042  0.013738
#                        5         0.012800  0.014819  0.015130  0.012532
#  ...                                  ...       ...       ...       ...
#                        116       0.004413  0.004587  0.004921  0.004984
#                        117       0.001299  0.001464  0.001950  0.002281
#                        118       0.016385  0.017072  0.017523  0.016313
#                        119       0.014547  0.015028  0.015135  0.013964
#                        120       0.002065  0.002525  0.004180  0.005632
#
#                                     13.0      14.0   ...     103.0     104.0  \
#  stimulation_condition trial_nr                      ...
#  baseline              1         0.002426  0.000749  ...  0.003792  0.003532
#                        2         0.014027  0.031595  ...  0.017174  0.016918
#                        3         0.009486  0.010299  ...  0.011951  0.011862
#                        4         0.015420  0.007585  ...  0.018369  0.018313
#                        5         0.010339  0.002055  ...  0.009991  0.009965
#  ...                                  ...       ...  ...       ...       ...
#                        116       0.004989  0.005136  ...  0.004968  0.004958
#                        117       0.002391  0.002345  ...  0.002967  0.002830
#                        118       0.015284  0.014437  ...  0.012460  0.013056
#                        119       0.012987  0.011983  ...  0.012562  0.012623
#                        120       0.006350  0.006840  ...  0.006940  0.006850
#
#                                     105.0     106.0     107.0     108.0  \
#  stimulation_condition trial_nr
#  baseline              1         0.003315  0.003131  0.002975  0.002843
#                        2         0.016648  0.016378  0.016115  0.015865
#                        3         0.011766  0.011666  0.011566  0.011470
#                        4         0.018219  0.018098  0.017961  0.017816
#                        5         0.009933  0.009897  0.009859  0.009821
#  ...                                  ...       ...       ...       ...
#                        116       0.004949  0.004943  0.004937  0.004933
#                        117       0.002730  0.002657  0.002603  0.002564
#                        118       0.013528  0.013894  0.014174  0.014385
#                        119       0.012666  0.012696  0.012717  0.012732
#                        120       0.006779  0.006725  0.006683  0.006653
#
#                                     109.0     110.0     111.0     112.0
#  stimulation_condition trial_nr
#  baseline              1         0.002732  0.002637  0.002556  0.002488
#                        2         0.015634  0.015422  0.015230  0.015058
#                        3         0.011378  0.011293  0.011216  0.011145
#                        118       0.004914  0.004917  0.004919  0.004920
#                        119       0.010062  0.010056  0.010051  0.010049
#                        120       0.011831  0.011834  0.011836  0.011838
#
#                                     109.0     110.0     111.0     112.0
#  stimulation_condition trial_nr
#  ips                   1         0.002852  0.002851  0.002851  0.002850
#                        2         0.006574  0.006574  0.006573  0.006573
#                        3         0.014992  0.014992  0.014992  0.014992
#                        4         0.013344  0.013345  0.013345  0.013345
#                        5         0.002136  0.002135  0.002135  0.002135
#  ...                                  ...       ...       ...       ...
#                        116       0.010732  0.010731  0.010731  0.010731
#                        117       0.000666  0.000666  0.000666  0.000666
#                        118       0.004921  0.004921  0.004922  0.004922
#                        119       0.010046  0.010045  0.010044  0.010043
#                        120       0.011839  0.011840  0.011840  0.011841
#
#  [120 rows x 108 columns],
#                                     5.0       6.0       7.0       8.0    \
#  stimulation_condition trial_nr
#  baseline              1         0.020689  0.009454  0.024257  0.019015
#                        2         0.002774  0.000207  0.000891  0.001311
#                        3         0.005391  0.012718  0.008954  0.002958
#                        4         0.001028  0.000774  0.000984  0.000557
#                        5         0.002597  0.000168  0.001310  0.003803
#  ...                                  ...       ...       ...       ...
#                        116       0.012409  0.005160  0.014138  0.009462
#                        117       0.002826  0.004370  0.001762  0.000391
#                        118       0.007808  0.001100  0.001506  0.000659
#                        119       0.008681  0.000988  0.008419  0.018433
#                        120       0.006844  0.000362  0.001174  0.001150
#
#                                     9.0       10.0      11.0      12.0   \
#  stimulation_condition trial_nr
#  baseline              1         0.017329  0.018913  0.024555  0.029150
#                        2         0.001195  0.001278  0.001316  0.001006
#                        3         0.002501  0.002802  0.003985  0.005762
#                        4         0.000487  0.000521  0.000574  0.000541
#                        5         0.003976  0.003978  0.003660  0.002657
#  ...                                  ...       ...       ...       ...
#                        116       0.006146  0.004358  0.002532  0.001454
#                        117       0.000237  0.000186  0.000131  0.000104
#                        118       0.000338  0.000305  0.000430  0.000569
#                        119       0.020943  0.031146  0.059802  0.070607
#                        120       0.000762  0.000698  0.000718  0.000671
#
#                                     13.0      14.0   ...     103.0     104.0  \
#  stimulation_condition trial_nr                      ...
#  baseline              1         0.026096  0.001698  ...  0.015278  0.015325
#                        2         0.000836  0.000022  ...  0.003279  0.003266
#                        3         0.006575  0.004498  ...  0.003944  0.003930
#                        4         0.000581  0.000243  ...  0.000887  0.000885
#                        5         0.002027  0.162393  ...  0.002683  0.002677
#  ...                                  ...       ...  ...       ...       ...
#                        116       0.002214  0.004736  ...  0.006720  0.006716
#                        117       0.000200  0.000568  ...  0.004208  0.004203
#                        118       0.000916  0.001352  ...  0.014605  0.014613
#                        119       0.066844  0.045736  ...  0.006340  0.006343
#                        120       0.001097  0.001908  ...  0.014668  0.014661
#
#                                     105.0     106.0     107.0     108.0  \
#  stimulation_condition trial_nr
#  baseline              1         0.015363  0.015392  0.015416  0.015435
#                        2         0.003256  0.003248  0.003242  0.003237
#                        3         0.003918  0.003909  0.003902  0.003896
#                        4         0.000884  0.000883  0.000882  0.000881
#                        120       3.220762e-15  8.898323e-11  0.000003
#
#                                     11.0      12.0      13.0      14.0   ...  \
#  stimulation_condition trial_nr                                          ...
#  baseline              1         0.010536  0.023108  0.034027  0.038161  ...
#                        2         0.012034  0.012713  0.011993  0.010027  ...
#                        3         0.045599  0.035810  0.031960  0.024910  ...
#                        4         0.020233  0.019763  0.014431  0.011952  ...
#                        5         0.000595  0.001200  0.001735  0.002373  ...
#  ...                                  ...       ...       ...       ...  ...
#                        116       0.004178  0.000003  0.000002  0.003542  ...
#                        117       0.004459  0.000047  0.000019  0.000332  ...
#                        118       0.000048  0.000018  0.000024  0.000006  ...
#                        119       0.038842  0.004255  0.003146  0.002261  ...
#                        120       0.000013  0.000002  0.000003  0.003437  ...
#
#                                     103.0     104.0     105.0     106.0  \
#  stimulation_condition trial_nr
#  baseline              1         0.014358  0.014349  0.014340  0.014331
#                        2         0.008124  0.008113  0.008103  0.008092
#                        3         0.007921  0.007847  0.007774  0.007703
#                        4         0.006595  0.006513  0.006433  0.006354
#                        5         0.004451  0.004422  0.004393  0.004365
#  ...                                  ...       ...       ...       ...
#                        116       0.014791  0.014791  0.014791  0.014791
#                        117       0.007116  0.007117  0.007117  0.007117
#                        118       0.000158  0.000158  0.000158  0.000158
#                        119       0.008248  0.008248  0.008248  0.008248
#                        120       0.000160  0.000160  0.000160  0.000160
#
#                                     107.0     108.0     109.0     110.0  \
#  stimulation_condition trial_nr
#  baseline              1         0.014322  0.014312  0.014302  0.014292
#                        2         0.008081  0.008070  0.008058  0.008047
#                        3         0.007632  0.007563  0.007495  0.007429
#                        4         0.006277  0.006201  0.006127  0.006054
#                        5         0.004337  0.004310  0.004283  0.004256
#  ...                                  ...       ...       ...       ...
#                        116       0.014791  0.014791  0.014791  0.014791
#                        117       0.007117  0.007118  0.007118  0.007118
#                        118       0.000158  0.000158  0.000158  0.000158
#                        119       0.008248  0.008248  0.008248  0.008248
#                        120       0.000160  0.000160  0.000160  0.000160
#
#                                     111.0     112.0
#  stimulation_condition trial_nr
#  baseline              1         0.014282  0.014271
#                        2         0.008035  0.008023
#                        3         0.007363  0.007298
#                        4         0.005982  0.005912
#                        5         0.004230  0.004204
#  ...                                  ...       ...
#                        116       0.014791  0.014791
#                        117       0.007118  0.007119
#                        118       0.000158  0.000158
#                        119       0.008248  0.008248
#                        120       0.000160  0.000160
#
#  [120 rows x 108 columns],
#                                     5.0           6.0       7.0    \
#  stimulation_condition trial_nr
#  ips                   1         0.000426  1.033517e-03  0.004302
#                        2         0.002439  1.807609e-03  0.002200
#                        3         0.002944  1.414120e-03  0.000540
#                        4         0.013020  3.686802e-02  0.047162
#                        5         0.000555  1.442781e-03  0.005660
#  ...                                  ...           ...       ...
#                        116       1.635077  1.926081e-03  0.010590
#                        117       0.000009  1.221479e-08  0.000089
#                        118       0.011808  2.627748e-08  0.000395
#                        119       0.000061  1.637644e-07  0.000067
#                        120       0.001879  4.549371e-06  0.154593
#
#                                         8.0           9.0       10.0   \
#  stimulation_condition trial_nr
#  ips                   1         5.168847e-04  6.921238e-03  0.007262
#                        2         4.783434e-04  9.297998e-04  0.000529
#                        3         1.683117e-05  7.498781e-05  0.000095
#                        4         2.409089e-03  2.110596e-02  0.039029
#                        5         7.692603e-04  1.001538e-02  0.011058
#  ...                                      ...           ...       ...
#                        116       1.270836e-13  1.167799e-08  0.015885
#                        117       9.712257e-15  9.120365e-10  0.001469
#                        118       1.137300e-14  1.146839e-09  0.106652
#                        119       3.027156e-14  1.314232e-09  0.000289
#                        120       4.323231e-11  1.482384e-05  0.384685
#
#                                     11.0      12.0      13.0      14.0   ...  \
#  stimulation_condition trial_nr                                          ...
#  ips                   1         0.008989  0.011294  0.012419  0.012303  ...
#                        2         0.000815  0.001513  0.002475  0.003102  ...
#                        3         0.000191  0.000446  0.000900  0.001446  ...
#                        4         0.040197  0.038991  0.034980  0.027651  ...
#                        5         0.013267  0.015875  0.016913  0.017528  ...
#  ...                                  ...       ...       ...       ...  ...
#                        116       0.016796  0.012375  0.009422  0.007476  ...
#                        117       0.003229  0.005866  0.008618  0.010965  ...
#                        118       0.210463  0.124919  0.075294  0.048549  ...
#                        119       0.000486  0.000687  0.000866  0.001007  ...
#                        120       0.078474  0.053014  0.035986  0.024978  ...
#
#                                     103.0     104.0     105.0     106.0  \
#  stimulation_condition trial_nr
#  ips                   1         0.002584  0.002569  0.002568  0.002580
#                        2         0.014984  0.014975  0.014974  0.014982
#                        3         0.002678  0.002672  0.002672  0.002676
#                        4         0.003020  0.003009  0.003008  0.003017
#                        5         0.000315  0.000312  0.000312  0.000314
#  ...                                  ...       ...       ...       ...
#                        116       0.000296  0.000321  0.000348  0.000377
#                        117       0.020927  0.022627  0.024396  0.026226
#                        118       0.000325  0.000344  0.000366  0.000389
#                        119       0.013383  0.012649  0.011962  0.011321
#                        120       0.000531  0.000554  0.000578  0.000604
#
#                                     107.0     108.0     109.0     110.0  \
#  stimulation_condition trial_nr
#  ips                   1         0.002605  0.002642  0.002691  0.002753
#                        2         0.014998  0.015020  0.015049  0.015084
#                        3         0.002686  0.002699  0.002717  0.002738
#                        4         0.003035  0.003063  0.003099  0.003145
#                        5         0.000319  0.000326  0.000336  0.000348
#  ...                                  ...       ...       ...       ...
#                        116       0.000408  0.000441  0.000476  0.000513
#                        117       0.028109  0.030034  0.031990  0.033967
#                        118       0.000414  0.000441  0.000471  0.000503
#                        119       0.010722  0.010164  0.009642  0.009156
#                        120       0.000632  0.000662  0.000694  0.000728
#
#                                     111.0     112.0
#  stimulation_condition trial_nr
#  ips                   1         0.002826  0.002913
#                        2         0.015121  0.015161
#                        3         0.002763  0.002792
#                        4         0.003199  0.003262
#                        5         0.000363  0.000381
#  ...                                  ...       ...
#                        116       0.000553  0.000595
#                        117       0.035950  0.037928
#                        118       0.000537  0.000574
#                        119       0.008703  0.008280
#                        120       0.000764  0.000803
#
#  [120 rows x 108 columns],
#                                         5.0           6.0       7.0    \
#  stimulation_condition trial_nr
#  vertex                1         1.529194e-06  6.741147e-07  0.000817
#                        2         8.127348e-06  2.168937e-03  0.051428
#                        3         7.198486e-02  2.998375e-08  0.001257
#                        4         4.293199e-06  2.160758e-06  0.014824
#                        5         4.593898e-06  5.866891e-03  0.098496
#  ...                                      ...           ...       ...
#                        116       2.089030e-05  5.270371e-03  0.050307
#                        117       1.100027e-07  2.242424e-08  0.000013
#                        118       3.767532e-09  1.585633e-09  0.000002
#                        119       6.862296e-05  2.896482e-05  0.066782
#                        120       7.124665e-09  5.737891e-06  0.002732
#
#                                         8.0       9.0       10.0      11.0   \
#  stimulation_condition trial_nr
#  vertex                1         1.352185e-03  0.001997  0.003144  0.003937
#                        2         7.858874e-04  0.000684  0.001166  0.001659
#                        3         1.934154e-01  0.154913  0.106823  0.075947
#                        4         3.039722e-02  0.051322  0.062425  0.061770
#                        5         1.407163e-03  0.001518  0.002200  0.002683
#  ...                                      ...       ...       ...       ...
#                        116       1.801840e-04  0.007026  0.028617  0.034578
#                        117       1.324584e-08  0.000016  0.004471  0.019772
#                        118       6.465928e-10  0.000006  0.000819  0.001689
#                        119       4.071066e-06  0.002501  0.061991  0.080480
#                        120       7.719258e-07  0.001233  0.021013  0.060050
#
#                                     12.0      13.0      14.0   ...     103.0  \
#  stimulation_condition trial_nr                                ...
#  vertex                1         0.003872  0.002968  0.005931  ...  0.023796
#                        2         0.001714  0.001172  0.000670  ...  0.006245
#                        3         0.051232  0.031371  0.001343  ...  0.000757
#                        4         0.061530  0.060577  0.006393  ...  0.016276
#                        5         0.002750  0.002359  0.000326  ...  0.018063
#  ...                                  ...       ...       ...  ...       ...
#                        116       0.032902  0.031884  0.039765  ...  0.001783
#                        117       0.025507  0.022555  0.010723  ...  0.001820
#                        118       0.002895  0.005218  0.007810  ...  0.010389
#                        119       0.068436  0.057972  0.044290  ...  0.005539
#                        120       0.093433  0.116001  0.143228  ...  0.002538
#
#                                     104.0     105.0     106.0     107.0  \
#  stimulation_condition trial_nr
#  vertex                1         0.024082  0.024363  0.024638  0.024908
#                        2         0.006132  0.006022  0.005916  0.005814
#                        3         0.000737  0.000718  0.000700  0.000683
#                        4         0.016480  0.016680  0.016877  0.017069
#                        5         0.018171  0.018274  0.018373  0.018469
#  ...                                  ...       ...       ...       ...
#                        116       0.001778  0.001772  0.001767  0.001762
#                        117       0.001819  0.001818  0.001816  0.001815
#                        118       0.010381  0.010372  0.010365  0.010357
#                        119       0.005529  0.005520  0.005510  0.005501
#                        120       0.002530  0.002522  0.002514  0.002507
#
#                                     108.0     109.0     110.0     111.0  \
#  stimulation_condition trial_nr
#  vertex                1         0.025171  0.025430  0.025683  0.025930
#                        2         0.005714  0.005618  0.005525  0.005435
#                        3         0.000666  0.000650  0.000635  0.000620
#                        4         0.017258  0.017443  0.017623  0.017801
#                        5         0.018560  0.018649  0.018733  0.018815
#  ...                                  ...       ...       ...       ...
#                        116       0.001758  0.001753  0.001748  0.001744
#                        117       0.001814  0.001813  0.001812  0.001811
#                        118       0.010350  0.010342  0.010335  0.010329
#                        119       0.005492  0.005484  0.005475  0.005467
#                        120       0.002500  0.002493  0.002486  0.002480
#
#                                     112.0
#  stimulation_condition trial_nr
#  vertex                1         0.026172
#                        2         0.005347
#                        3         0.000606
#                        4         0.017974
#                        5         0.018893
#  ...                                  ...
#                        116       0.001740
#                        117       0.001810
#                        118       0.010322
#                        119       0.005459
#                        120       0.002473
#
#  [120 rows x 108 columns]]

# %%
pred = pd.concat([p for p in pred if p.shape[0] != 0])
pdf =pd.concat([p for p in pdfs if p.shape[0] != 0])
df = get_all_behavior(drop_no_responses=False)
# Out:
# /Users/gdehol/git/tms_risk/tms_risk/utils/data.py:156: UserWarning: Subject 10/session 1 has only 5 runs!!
#   warnings.warn('Subject 10/session 1 has only 5 runs!!')
# /Users/gdehol/git/tms_risk/tms_risk/utils/data.py:279: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '20%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '32%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '44%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '56%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '68%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%', '80%']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   d[d.sort_values().index] = [labels[e] for e in np.floor(ix).astype(int)]

# %%
df.join(pred, on=['subject', 'session', ])
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_29566/2171777414.py", line 1, in <module>
#     df.join(pred, on=['subject', 'session', ])
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/pandas/core/frame.py", line 10412, in join
#     return merge(
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/pandas/core/reshape/merge.py", line 169, in merge
#     op = _MergeOperation(
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/pandas/core/reshape/merge.py", line 783, in __init__
#     self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/pandas/core/reshape/merge.py", line 1573, in _validate_left_right_on
#     raise ValueError(
# ValueError: len(left_on) must equal the number of levels in the index of "right"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/IPython/core/ultratb.py", line 799, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/IPython/core/ultratb.py", line 845, in get_records
#     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/stack_data/core.py", line 455, in style_with_executing_node
#     class NewStyle(style):
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/pygments/style.py", line 66, in __new__
#     ndef[4] = colorformat(styledef[3:])
#   File "/Users/gdehol/mambaforge/lib/python3.10/site-packages/pygments/style.py", line 33, in colorformat
#     assert False, "wrong color format %r" % text
# AssertionError: wrong color format 'ansiyellow'

# %%
pred = pred.join(df, how='inner')
r1 = pred.groupby(['subject', 'session', 'stimulation_condition', 'pca', 'glm', 'smoothed', 'mask', 'n_voxels']).apply(lambda d: pingouin.corr(d['E'], d['n1']))
r2_ = pred.groupby(['subject', 'session', 'stimulation_condition', 'pca', 'glm', 'smoothed', 'mask', 'n_voxels', 'run']).apply(lambda d: pingouin.corr(d['E'], d['n1']))
r2 = r2_.groupby(['subject', 'session', 'stimulation_condition', 'pca', 'glm', 'smoothed', 'mask', 'n_voxels'])[['r']].mean()

# %%
pred['Order'] = pred['risky_first'].map({True:'Risky first', False:'Safe first'})

# %%
r3_ = pred.groupby(['subject', 'session', 'stimulation_condition', 'pca', 'glm', 'smoothed', 'mask', 'n_voxels', 'run', 'Order']).apply(lambda d: pingouin.corr(d['E'], d['n1']))
r3 = r3_.groupby(['subject', 'session', 'stimulation_condition', 'pca', 'glm', 'smoothed', 'mask', 'n_voxels', 'Order'])['r'].mean()

# %%
pred['Stimulation condition'] = pred.index.get_level_values('stimulation_condition').map({'vertex': 'Vertex', 'ips': 'IPS', 'baseline':'Baseline'})
pred.set_index('Stimulation condition', append=True, inplace=True)

# %%
g = sns.catplot(x='n_voxels', y='r', hue='stimulation_condition',data=r2.reset_index(), col='mask', kind='swarm', row='smoothed', dodge=True, ci=67)
g.map(lambda *args, **kwargs: plt.axhline(0, c='k', ls='--'))
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_29566/2816764074.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 67)` for the same effect.
#
#   g = sns.catplot(x='n_voxels', y='r', hue='stimulation_condition',data=r2.reset_index(), col='mask', kind='swarm', row='smoothed', dodge=True, ci=67)

# %%
g = sns.catplot(x='stimulation_condition', y='r', data=r2.drop('baseline', level='stimulation_condition').reset_index(), col='mask', kind='point', dodge=True, ci=67, palette=['k'])
g.map(lambda *args, **kwargs: plt.axhline(0, c='k', ls='--'))


g.set(ylabel='Decoding accuracy (r)', xlabel='Stimulation condition')
g.set_xticklabels(['Vertex', 'IPS'])




g.savefig(op.join(bids_folder, 'derivatives', 'figures', 'decoding.pdf'))
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_29566/1375396775.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x='stimulation_condition', y='r', data=r2.drop('baseline', level='stimulation_condition').reset_index(), col='mask', kind='point', dodge=True, ci=67, palette=['k'])
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_29566/1375396775.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 67)` for the same effect.
#
#   g = sns.catplot(x='stimulation_condition', y='r', data=r2.drop('baseline', level='stimulation_condition').reset_index(), col='mask', kind='point', dodge=True, ci=67, palette=['k'])
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_29566/1375396775.py:1: UserWarning:
# The palette list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   g = sns.catplot(x='stimulation_condition', y='r', data=r2.drop('baseline', level='stimulation_condition').reset_index(), col='mask', kind='point', dodge=True, ci=67, palette=['k'])

# %%
r2.groupby(['stimulation_condition', 'mask']).mean()
# Out:
#                                               r
# stimulation_condition mask
# baseline              NPCr2cm-cluster  0.051925
# ips                   NPCr2cm-cluster  0.097076
# vertex                NPCr2cm-cluster  0.121811

# %%
r2.groupby('subject').mean().sort_values('r')
# Out:
#                 r
# subject
# 26      -0.096701
# 2       -0.059180
# 6       -0.034580
# 9       -0.032270
# 56      -0.019071
# 47      -0.010837
# 34      -0.004625
# 67      -0.003230
# 35       0.000813
# 1        0.008320
# 31       0.033784
# 4        0.037407
# 46       0.039389
# 29       0.055822
# 21       0.061972
# 30       0.075761
# 50       0.080496
# 36       0.086449
# 53       0.088630
# 69       0.088838
# 74       0.091278
# 3        0.096109
# 45       0.119908
# 72       0.141428
# 37       0.157370
# 5        0.158774
# 10       0.167939
# 62       0.171278
# 7        0.196995
# 25       0.203288
# 19       0.216417
# 63       0.228362
# 59       0.247201
# 18       0.264520
# 11       0.324084

# %%
r2.loc[72]
# Out:
#                                                                                        n  \
# session stimulation_condition pca    glm     smoothed     mask            n_voxels
# 1       baseline              no pca GLMstim not smoothed NPCr2cm-cluster 1         20.0
# 2       ips                   no pca GLMstim not smoothed NPCr2cm-cluster 1         20.0
# 3       vertex                no pca GLMstim not smoothed NPCr2cm-cluster 1         20.0
#
#                                                                                            r  \
# session stimulation_condition pca    glm     smoothed     mask            n_voxels
# 1       baseline              no pca GLMstim not smoothed NPCr2cm-cluster 1         0.465962
# 2       ips                   no pca GLMstim not smoothed NPCr2cm-cluster 1         0.188508
# 3       vertex                no pca GLMstim not smoothed NPCr2cm-cluster 1         0.296474
#
#                                                                                        p-val  \
# session stimulation_condition pca    glm     smoothed     mask            n_voxels
# 1       baseline              no pca GLMstim not smoothed NPCr2cm-cluster 1         0.060531
# 2       ips                   no pca GLMstim not smoothed NPCr2cm-cluster 1         0.430521
# 3       vertex                no pca GLMstim not smoothed NPCr2cm-cluster 1         0.233691
#
#                                                                                        power
# session stimulation_condition pca    glm     smoothed     mask            n_voxels
# 1       baseline              no pca GLMstim not smoothed NPCr2cm-cluster 1         0.561106
# 2       ips                   no pca GLMstim not smoothed NPCr2cm-cluster 1         0.178088
# 3       vertex                no pca GLMstim not smoothed NPCr2cm-cluster 1         0.354746

# %%
tmp = r2.drop('baseline', level='stimulation_condition').reset_index()

pingouin.rm_anova(tmp, 'r', 'stimulation_condition', 'subject')
# Out:
#                   Source  ddof1  ddof2         F     p-unc      ng2  eps
# 0  stimulation_condition      1     34  4.992127  0.032145  0.04188  1.0

# %%
g = sns.catplot(hue='stimulation_condition', y='r', x='Order', data=r3.drop('baseline', level='stimulation_condition').reset_index(), col='mask', kind='point', dodge=True, ci=67, palette=stimulation_palette)
g.map(lambda *args, **kwargs: plt.axhline(0, c='k', ls='--'))


g.set(ylabel='Decoding accuracy (r)')




g.savefig(op.join(bids_folder, 'derivatives', 'figures', 'decoding.pdf'))
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_3770/1369163544.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 67)` for the same effect.
#
#   g = sns.catplot(hue='stimulation_condition', y='r', x='Order', data=r3.drop('baseline', level='stimulation_condition').reset_index(), col='mask', kind='point', dodge=True, ci=67, palette=stimulation_palette)

# %%
# Out:
#                   Source  ddof1  ddof2         F     p-unc      ng2  eps
# 0  stimulation_condition      1     34  4.992127  0.032145  0.04188  1.0

# %%
tmp = r3.drop('baseline', level='stimulation_condition').reset_index()

pingouin.rm_anova(tmp, 'r', ['stimulation_condition', 'Order'], 'subject')
# Out:
#                           Source        SS  ddof1  ddof2        MS         F  \
# 0          stimulation_condition  0.082271      1     34  0.082271  2.677735
# 1                          Order  0.021254      1     34  0.021254  0.794790
# 2  stimulation_condition * Order  0.016769      1     34  0.016769  0.861296
#
#       p-unc  p-GG-corr       ng2  eps
# 0  0.110985   0.110985  0.018626  1.0
# 1  0.378922   0.378922  0.004879  1.0
# 2  0.359918   0.359918  0.003854  1.0

# %% [markdown]
# # Get the noise increase for each subject for flexible model

# %%
from tms_risk.cogmodels.fit_model import build_model, get_data

# %%
tmp = r2.xs('NPCr2cm-cluster', 0, 'mask').xs(1, 0, 'n_voxels').droplevel('session').unstack('stimulation_condition')['r']

pingouin.ttest(tmp['ips'], tmp['vertex'], True)
# Out:
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -2.234307   34   two-sided  0.032145  [-0.09, -0.0]  0.412123  1.611
#
#            power
# T-test  0.658698

# %%
pred['n_bin'] = pd.cut(pred['n1'], np.arange(5, 100, 5), labels=np.arange(7.5, 97.5, 5))

# %%
pred['n_bin_q'] = pd.qcut(pred['n1'], 7)

pred['n_bin_q'] = pred['n_bin_q'].apply(lambda x: x.mid)

# %%
tmp = pred.xs('NPCr2cm-cluster', 0, 'mask').xs(1, 0, 'n_voxels').groupby(['subject', 'stimulation_condition', 'n_bin']).mean().drop('baseline', level='stimulation_condition')

sns.lineplot(x='n_bin', y='sd', hue='stimulation_condition', data=tmp.reset_index(), errorbar='se')
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_94923/3079950012.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tmp = pred.xs('NPCr2cm-cluster', 0, 'mask').xs(1, 0, 'n_voxels').groupby(['subject', 'stimulation_condition', 'n_bin']).mean().drop('baseline', level='stimulation_condition')
# <Axes: xlabel='n_bin', ylabel='sd'>

# %%
tmp = pred.xs('NPCr2cm-cluster', 0, 'mask').xs(1, 0, 'n_voxels').groupby(['subject', 'Stimulation condition', 'n_bin_q']).mean().drop('Baseline', level='Stimulation condition')

g = sns.lineplot(x='n_bin_q', y='sd', hue='Stimulation condition', data=tmp.reset_index(), errorbar='se', palette=stimulation_palette, hue_order=stimulation_order, legend=False)

g.set(xlabel='Mu (binned)', ylabel='Decoded uncertainty (sd of posterior)')



# g.add_legend()
sns.despine()

plt.savefig(op.join(bids_folder, 'derivatives', 'figures', 'decoding_sd.pdf'))
# g.savefig()
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_94923/888137233.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tmp = pred.xs('NPCr2cm-cluster', 0, 'mask').xs(1, 0, 'n_voxels').groupby(['subject', 'Stimulation condition', 'n_bin_q']).mean().drop('Baseline', level='Stimulation condition')

# %%
pred['error'] = pred['n1'] - pred['E']
pred['abs(error)'] = np.abs(pred['error'])

# %%
tmp = pred.xs('NPCr2cm-cluster', 0, 'mask').xs(1, 0, 'n_voxels').groupby(['subject', 'Stimulation condition', 'n_bin_q']).mean().drop('Baseline', level='Stimulation condition')

sns.lineplot(x='n_bin_q', y='abs(error)', hue='Stimulation condition', data=tmp.reset_index(), errorbar='se', palette=stimulation_palette, hue_order=stimulation_order, legend=False)

plt.xlim(5, 40)
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_94923/962597191.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tmp = pred.xs('NPCr2cm-cluster', 0, 'mask').xs(1, 0, 'n_voxels').groupby(['subject', 'Stimulation condition', 'n_bin_q']).mean().drop('Baseline', level='Stimulation condition')
# (5.0, 40.0)

# %% [markdown]
# # 12 a-priori ROIs

# %%
subjects = [int(sub.subject) for sub in get_subjects(all_tms_conditions=True, exclude_outliers=True)]
sessions = [1, 2, 3]
pca_confounds = [False]
denoise = [True]
smoothed = [False]
# masks = ['NPCr1cm-surface', 'NPCr1cm-cluster', 'NPCr2cm-surface', 'NPCr2cm-cluster']
# n_voxels = [0, 1, 100]
masks = get_all_apriori_roi_labels()
n_voxels = [1]
natural_space = [True]


pred = []
pdfs = []
for (sub, session, pcac, den, smooth, mask, nv, ns) in product(subjects, sessions, pca_confounds, denoise, smoothed, masks, n_voxels, natural_space):

    if not ((session == 1) & (nv == 0)):
        pdfs.append(get_pdf(sub, session, pcac, den, smooth, '/data/ds-tmsrisk/', mask, nv, ns))
        pred.append(get_decoding_info(sub, session, pcac, den, smooth, '/data/ds-tmsrisk', mask, nv, ns))
# Out:
#   0%|          | 0/1260 [00:00<?, ?it/s]
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-03/func/sub-03_ses-3_mask-NF1r_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-03/func/sub-03_ses-3_mask-NF1r_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-04/func/sub-04_ses-3_mask-NF2r_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-04/func/sub-04_ses-3_mask-NF2r_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-21/func/sub-21_ses-1_mask-NF2l_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-21/func/sub-21_ses-1_mask-NF2l_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-21/func/sub-21_ses-1_mask-NF2r_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-21/func/sub-21_ses-1_mask-NF2r_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-21/func/sub-21_ses-2_mask-NPC1l_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-21/func/sub-21_ses-2_mask-NPC1l_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-21/func/sub-21_ses-2_mask-NPC1r_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-21/func/sub-21_ses-2_mask-NPC1r_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-31/func/sub-31_ses-3_mask-NTOl_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-31/func/sub-31_ses-3_mask-NTOl_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-35/func/sub-35_ses-2_mask-NPC1l_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-35/func/sub-35_ses-2_mask-NPC1l_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-35/func/sub-35_ses-2_mask-NPC1r_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-35/func/sub-35_ses-2_mask-NPC1r_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-35/func/sub-35_ses-2_mask-NPC3l_space-T1w_pars.tsv
# /data/ds-tmsrisk/derivatives/decoded_pdfs.volume.cv_voxel_selection.denoise.natural_space/sub-35/func/sub-35_ses-2_mask-NPC3l_space-T1w_pars.tsv

# %%
pred = pd.concat(pred)
pdf = pd.concat(pdfs)
df = get_all_behavior(drop_no_responses=False)
pred = pred.join(df, how='inner')
r1 = pred.groupby(['subject', 'session', 'stimulation_condition', 'pca', 'glm', 'smoothed', 'mask', 'n_voxels']).apply(lambda d: pingouin.corr(d['E'], d['n1']))
r2_ = pred.groupby(['subject', 'session', 'stimulation_condition', 'pca', 'glm', 'smoothed', 'mask', 'n_voxels', 'run']).apply(lambda d: pingouin.corr(d['E'], d['n1']))
r2 = r2_.groupby(['subject', 'session', 'stimulation_condition', 'pca', 'glm', 'smoothed', 'mask', 'n_voxels']).mean()
# Out:
# /Users/gdehol/git/tms_risk/tms_risk/utils/data.py:150: UserWarning: Subject 10/session 1 has only 5 runs!!
#   warnings.warn('Subject 10/session 1 has only 5 runs!!')
# /Users/gdehol/git/tms_risk/tms_risk/utils/data.py:56: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return pd.concat(behavior)
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_3770/884262180.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   r2 = r2_.groupby(['subject', 'session', 'stimulation_condition', 'pca', 'glm', 'smoothed', 'mask', 'n_voxels']).mean()

# %%
sns.catplot(x='mask', y='r', hue='stimulation_condition', data=r2.reset_index(), kind='bar', aspect=3.)

# %%
# Out:
# stimulation_condition                                 vertex       ips
# subject pca    glm     smoothed     mask  n_voxels
# 1       no pca GLMstim not smoothed NF1l  1        -0.048457  0.076244
#                                     NF1r  1        -0.064500 -0.102049
#                                     NF2l  1         0.022710  0.111842
#                                     NF2r  1         0.073933  0.068484
#                                     NPC1l 1        -0.100284  0.178181
# ...                                                      ...       ...
# 74      no pca GLMstim not smoothed NPC2r 1         0.071207  0.058015
#                                     NPC3l 1         0.148896 -0.074379
#                                     NPC3r 1         0.245499  0.118568
#                                     NTOl  1         0.092867 -0.070679
#                                     NTOr  1         0.215037 -0.051036
#
# [420 rows x 2 columns]

# %%
r2.droplevel('session').drop('baseline', level='stimulation_condition')['r'].unstack('stimulation_condition').groupby(['mask']).apply(lambda d: pingouin.ttest(d['ips'], d['vertex'], paired=True)).sort_values('p-val')
# Out:
#                      T  dof alternative     p-val           CI95%   cohen-d  \
# mask
# NPC2l T-test -2.767637   34   two-sided  0.009071  [-0.09, -0.01]  0.414161
# NF1r  T-test -1.757250   33   two-sided  0.088151    [-0.1, 0.01]  0.333656
# NF1l  T-test -1.388715   34   two-sided  0.173950    [-0.1, 0.02]  0.262510
# NTOl  T-test -1.207212   33   two-sided  0.235932   [-0.09, 0.02]  0.270159
# NPC2r T-test -1.161636   34   two-sided  0.253474   [-0.08, 0.02]  0.251968
# NTOr  T-test -0.751071   34   two-sided  0.457777   [-0.08, 0.03]  0.145036
# NPC1r T-test -0.562912   32   two-sided  0.577418   [-0.07, 0.04]  0.112976
# NF2r  T-test -0.453986   33   two-sided  0.652811   [-0.06, 0.04]  0.105935
# NF2l  T-test -0.337607   34   two-sided  0.737735   [-0.07, 0.05]  0.084534
# NPC3r T-test -0.095155   34   two-sided  0.924750   [-0.07, 0.06]  0.020628
# NPC3l T-test  0.039357   33   two-sided  0.968843   [-0.05, 0.05]  0.007931
# NPC1l T-test -0.037495   32   two-sided  0.970323   [-0.05, 0.05]  0.007405
#
#                BF10     power
# mask
# NPC2l T-test  4.644  0.662981
# NF1r  T-test  0.731  0.471698
# NF1l  T-test  0.437  0.326358
# NTOl  T-test  0.358  0.333679
# NPC2r T-test  0.337  0.304897
# NTOr  T-test  0.236  0.132693
# NPC1r T-test  0.216  0.096521
# NF2r  T-test  0.202  0.092141
# NF2l  T-test  0.191  0.077484
# NPC3r T-test  0.182  0.051614
# NPC3l T-test  0.184  0.050231
# NPC1l T-test  0.186  0.050195

# %%
tmp = r2.droplevel('session').unstack(['stimulation_condition'])['r']

diff = (tmp['ips'] - tmp['vertex']).to_frame('diff')

sns.catplot(x='mask', y='diff', data=diff.reset_index(), kind='point', aspect=2.5)
plt.axhline(0.0, c='k', ls='--')

# %%
sns.heatmap(r2['r'].unstack('mask').corr(), cmap='viridis')
# Out:
# <Axes: xlabel='mask', ylabel='mask'>

# %%
sns.catplot(x='mask', y='r', data=r2.groupby(['subject', 'mask']).mean().reset_index(), kind='bar', aspect=3., color='gray', errorbar='se')

# %%
r2.groupby(['subject', 'session', 'mask']).size().groupby(['mask', 'session']).size()
# Out:
# mask   session
# NF1l   1          35
#        2          35
#        3          35
# NF1r   1          35
#        2          35
#        3          34
# NF2l   1          34
#        2          35
#        3          35
# NF2r   1          34
#        2          35
#        3          34
# NPC1l  1          35
#        2          33
#        3          35
# NPC1r  1          35
#        2          33
#        3          35
# NPC2l  1          35
#        2          35
#        3          35
# NPC2r  1          35
#        2          35
#        3          35
# NPC3l  1          35
#        2          34
#        3          35
# NPC3r  1          35
#        2          35
#        3          35
# NTOl   1          35
#        2          35
#        3          34
# NTOr   1          35
#        2          35
#        3          35
# dtype: int64
